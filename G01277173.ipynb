# %%
import os
import pandas as pd
os.getcwd()
os.chdir('C:/Users/sirir/OneDrive/Desktop/AIT 580/AIT 580 PROJECT')

# %%
foodtypes=pd.read_csv('C:/Users/sirir/OneDrive/Desktop/AIT 580/AIT 580 PROJECT/Foodtypequantity.csv')

# %%
import matplotlib.pyplot as plt
foodtypes.plot.box(figsize=(30,10))
plt.title("Statistical Summary of import quantity of different food types over the period of 1999 to 2017")
# Out:
# Text(0.5, 1.0, 'Statistical Summary of import quantity of different food types over the period of 1999 to 2017')

# %%
corr=foodtypes.corr()

# %%
corr.head()
# Out:
#                     Live meat animals     Meats  Fish and shellfish     Dairy  \
# Live meat animals            1.000000  0.645337            0.691269  0.741966
# Meats                        0.645337  1.000000            0.900130  0.906147
# Fish and shellfish           0.691269  0.900130            1.000000  0.941438
# Dairy                        0.741966  0.906147            0.941438  1.000000
# Vegetables                   0.649247  0.875176            0.985064  0.947726
#
#                     Vegetables    Fruits      Nuts  Coffee, tea, and spices  \
# Live meat animals     0.649247  0.649620  0.560637                 0.602529
# Meats                 0.875176  0.891552  0.923859                 0.761098
# Fish and shellfish    0.985064  0.984410  0.962969                 0.925426
# Dairy                 0.947726  0.936447  0.902373                 0.847173
# Vegetables            1.000000  0.990722  0.958603                 0.932878
#
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(corr, annot=True)
plt.show()
